-- %% [markdown]
-- [https://www.dofactory.com/net/proxy-design-pattern](https://www.dofactory.com/net/proxy-design-pattern)
--
-- [https://refactoring.guru/pt-br/design-patterns/chain-of-responsibility](https://refactoring.guru/pt-br/design-patterns/bridge)
--
-- https://codewithshadman.com/

-- %% [markdown]
-- ![](attachment:image.png)

-- %% [markdown]
-- ![](attachment:image.png)

-- %% [markdown]
-- ![](attachment:image.png)

-- %% [markdown]
-- ![](attachment:image.png)

-- %% [markdown]
-- ![](attachment:image.png)

-- %% [markdown]
-- ![](attachment:image.png)

-- %% [markdown]
-- ![](attachment:image.png)

-- %% [markdown]
-- # \# Estutura Diagrama de Classes

-- %% [markdown]
-- - ![](attachment:image.png)

-- %% [markdown]
-- ![](attachment:image.png)

-- %% [markdown]
-- ![](attachment:image.png)

-- %% [markdown]
-- ![](attachment:image.png)

-- %% [markdown]
-- # \# Demo

-- %% [markdown]
-- ![](attachment:image.png)
