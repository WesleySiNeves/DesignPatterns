-- %% [markdown]
-- [https://www.dofactory.com/net/proxy-design-pattern](https://www.dofactory.com/net/proxy-design-pattern)
--
-- [https://www.dofactory.com/net/command-design-pattern](https://refactoring.guru/pt-br/design-patterns/bridge)
--
-- [https://codewithshadman.com/](https://codewithshadman.com/)

-- %% [markdown]
-- ![](attachment:image.png)

-- %% [markdown]
-- Principais caracteristicas
--
-- ![](attachment:image.png)

-- %% [markdown]
-- ![](attachment:image.png)

-- %% [markdown]
-- ![](attachment:image.png)

-- %% [markdown]
-- ![](attachment:image.png)

-- %% [markdown]
-- ![](attachment:image.png)

-- %% [markdown]
-- ## UML class diagram
--
-- # ![](attachment:image.png)

-- %% [markdown]
-- ## Participants
--
--
--
-- ![](attachment:image.png)

-- %% [markdown]
-- ![](attachment:image.png)

-- %% [markdown]
-- ![](attachment:image.png)

-- %% [markdown]
-- -

-- %% [markdown]
-- ![](attachment:image.png)

-- %% [markdown]
-- ![](attachment:image.png)

-- %% [markdown]
-- # \# Demo
