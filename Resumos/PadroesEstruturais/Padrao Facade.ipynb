-- %% [markdown]
-- [https://www.dofactory.com/net/proxy-design-pattern](https://www.dofactory.com/net/proxy-design-pattern)
-- [https://refactoring.guru/pt-br/design-patterns](https://www.dofactory.com/net/facade-design-pattern)
--
-- https://www.youtube.com/watch?v=8tyNCznvgW8

-- %% [markdown]
-- ![](attachment:image.png)

-- %% [markdown]
-- ![](attachment:image.png)

-- %% [markdown]
-- ![](attachment:image.png)

-- %% [markdown]
-- ![](attachment:image.png)

-- %% [markdown]
-- ![](attachment:image.png)

-- %% [markdown]
-- ![](attachment:image.png)

-- %% [markdown]
-- ![](attachment:image.png)

-- %% [markdown]
-- ![](attachment:image.png)

-- %% [markdown]
-- ![](attachment:image.png)

-- %% [markdown]
-- ![](attachment:image.png)

-- %% [markdown]
-- ![](attachment:image.png)

-- %% [markdown]
-- ![](attachment:image.png)

-- %% [markdown]
-- # **Vantagens**
--
-- ![](attachment:image.png)
